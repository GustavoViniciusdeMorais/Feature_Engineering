# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
taxi = sns.load_dataset("taxis")

# %%
# q-q test to verify normally distributed data column
stats.probplot(taxi["tip"], dist="norm", plot=plt)
plt.show()
